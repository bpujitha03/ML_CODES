# %%
#simple linear regression
# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Admission.csv')
df
# Out:
#      serialno.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1        337          118                  4  4.5   4.5  9.65
# 1            2        324          107                  4  4.0   4.5  8.87
# 2            3        316          104                  3  3.0   3.5  8.00
# 3            4        322          110                  3  3.5   2.5  8.67
# 4            5        314          103                  2  2.0   3.0  8.21
# ..         ...        ...          ...                ...  ...   ...   ...
# 495        496        332          108                  5  4.5   4.0  9.02
# 496        497        337          117                  5  5.0   5.0  9.87
# 497        498        330          120                  5  4.5   5.0  9.56
# 498        499        312          103                  4  4.0   5.0  8.43
# 499        500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
#list out top values of dataset
df.head()
# Out:
#    serialno.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0          1        337          118                  4  4.5   4.5  9.65
# 1          2        324          107                  4  4.0   4.5  8.87
# 2          3        316          104                  3  3.0   3.5  8.00
# 3          4        322          110                  3  3.5   2.5  8.67
# 4          5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
#Data Inspection
df.shape
# Out:
# (500, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of      serialno.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1        337          118                  4  4.5   4.5  9.65
# 1            2        324          107                  4  4.0   4.5  8.87
# 2            3        316          104                  3  3.0   3.5  8.00
# 3            4        322          110                  3  3.5   2.5  8.67
# 4            5        314          103                  2  2.0   3.0  8.21
# ..         ...        ...          ...                ...  ...   ...   ...
# 495        496        332          108                  5  4.5   4.0  9.02
# 496        497        337          117                  5  5.0   5.0  9.87
# 497        498        330          120                  5  4.5   5.0  9.56
# 498        499        312          103                  4  4.0   5.0  8.43
# 499        500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
df.describe()
# Out:
#         serialno.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
#Data Cleaning
# Checking Null values
df.isnull().sum()*100/df.shape[0]
# There are no NULL values in the dataset, hence it is clean.
# Out:
# serialno.            0.0
# GRE Score            0.0
# TOEFL Score          0.0
# University Rating    0.0
# SOP                  0.0
# LOR                  0.0
# CGPA                 0.0
# Research             0.0
# Chance of Admit      0.0
# dtype: float64

# %%
# Outlier Analysis
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['GRE Score'], ax = axs[0])
plt2 = sns.boxplot(df['CGPA'], ax = axs[1])
plt3 = sns.boxplot(df['TOEFL Score'], ax = axs[2])
plt.tight_layout()

# %%
#Exploratory Data Analysis
sns.boxplot(df['CGPA'])
plt.show()

# %%
# Let's see how Sales are related with other variables using scatter plot.
sns.pairplot(df, x_vars=['CGPA', 'GRE Score', 'TOEFL Score'], y_vars='Research', height=4, aspect=1, kind='scatter')
plt.show()
# Out:
# D:\jupyter\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x="CGPA",y="LOR",data=df,kind="reg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.jointplot(x="CGPA",y="LOR",data=df,kind="reg")
#       2 plt.show()
#
# File D:\jupyter\Lib\site-packages\seaborn\axisgrid.py:2241, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2238     dropna = True
#    2240 # Initialize the JointGrid object
# -> 2241 grid = JointGrid(
#    2242     data=data, x=x, y=y, hue=hue,
#    2243     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2244     dropna=dropna, height=height, ratio=ratio, space=space,
#    2245     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2246 )
#    2248 if grid.hue is not None:
#    2249     marginal_kws.setdefault("legend", False)
#
# ...
